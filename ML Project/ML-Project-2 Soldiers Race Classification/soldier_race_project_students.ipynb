# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
import pandas as pd      
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from scipy.stats import skew

from sklearn.model_selection import cross_validate
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["figure.figsize"] = (10,6)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
dfmale = pd.read_csv("ANSUR II MALE Public.csv", encoding="latin-1")
dfmale.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# 2                      256               196                427
# 3                      262               199                401
# 4                      267               224                435
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        369               274               493
# 1                        338               257               479
# 2                        408               261               544
# 3                        359               262               518
# 4                        356               263               524
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  71               319                        291
# 1                  67               344                        320
# 2                  75               345                        330
# 3                  73               328                        309
# 4                  80               340                        310
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 142                   979           240            882
# 1                 135                   944           232            870
# 2                 135                  1054           258            901
# 3                 143                   991           242            821
# 4                 138                  1029           275           1080
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                619                     509                373
# 1                584                     468                357
# 2                623                     506                412
# 3                560                     437                395
# 4                706                     567                425
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1535           291                1074         259         1292
# 1             1471           269                1021         253         1244
# 2             1501           288                1120         267         1288
# 3             1423           296                1114         262         1205
# 4             1684           304                1048         232         1452
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           877                    607                             351
# 1           851                    615                             376
# 2           854                    636                             359
# 3           769                    590                             341
# 4          1014                    682                             382
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          36         71             19              247               802
# 1          33         62             18              232               781
# 2          40         61             23              237               810
# 3          39         66             25              272               794
# 4          32         56             19              188               814
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                    101         273                        349
# 1                     98         263                        348
# 2                    103         270                        355
# 3                    106         267                        352
# 4                    111         305                        399
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         299                    575                477
# 1                         289                    523                476
# 2                         357                    575                491
# 3                         318                    593                467
# 4                         324                    605                550
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1136           90                214         193
# 1                 1096           86                203         195
# 2                 1115           93                220         203
# 3                 1034           91                217         194
# 4                 1279           94                222         218
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          150                583         206                     326
# 1          146                568         201                     334
# 2          148                573         202                     356
# 3          158                576         199                     341
# 4          153                566         197                     374
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           70         332                366                1071
# 1           72         312                356                1046
# 2           70         349                393                1053
# 3           68         338                367                 986
# 4           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    685         422          441                   502
# 1                    620         441          447                   490
# 2                    665         462          475                   496
# 3                    640         458          461                   460
# 4                    675         481          505                   612
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                560                             500                      77
# 1                540                             488                      73
# 2                556                             482                      72
# 3                511                             452                      76
# 4                666                             585                      85
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      391                  118                400
# 1                      371                  131                380
# 2                      409                  123                403
# 3                      393                  106                407
# 4                      458                  135                398
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    436                           1447         113
# 1                    420                           1380         118
# 2                    434                           1447         121
# 3                    446                           1357         118
# 4                    430                           1572         132
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              437                   273                   1151
# 1              417                   254                   1119
# 2              431                   268                   1276
# 3              393                   249                   1155
# 4              523                   302                   1231
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  368             145            928                     883
# 1                  353             141            884                     868
# 2                  367             167            917                     910
# 3                  330             148            903                     848
# 4                  400             180            919                     995
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            600  1782     1776                 1449            1092
# 1            564  1745     1702                 1387            1076
# 2            604  1867     1735                 1438            1105
# 3            550  1708     1655                 1346            1021
# 4            641  2035     1914                 1596            1292
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 610             164            786           491
# 1                 572             169            822           476
# 2                 685             198            807           477
# 3                 604             180            803           445
# 4                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               140                  919                           1700
# 1               120                  918                           1627
# 2               125                  918                           1678
# 3               127                  847                           1625
# 4               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              501           329                 933         240
# 1              432           316                 870         225
# 2              472           329                 964         255
# 3              461           315                 857         205
# 4              467           303                 868         214
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      440                  1054       815
# 1                      371                  1054       726
# 2                      411                  1041       929
# 3                      399                   968       794
# 4                      379                  1245       946
#
#    wristcircumference  wristheight Gender       Date Installation  \
# 0                 175          853   Male   4-Oct-10    Fort Hood
# 1                 167          815   Male   4-Oct-10    Fort Hood
# 2                 180          831   Male   4-Oct-10    Fort Hood
# 3                 176          793   Male  12-Oct-10    Fort Hood
# 4                 188          954   Male  12-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army             Combat Arms        19D          North Dakota
# 1  Regular Army          Combat Support        68W              New York
# 2  Regular Army          Combat Support        68W              New York
# 3  Regular Army  Combat Service Support        88M             Wisconsin
# 4  Regular Army  Combat Service Support        92G        North Carolina
#
#    SubjectNumericRace Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   1       NaN        1   41        71        180
# 1                   1       NaN        1   35        68        160
# 2                   2       NaN        2   42        68        205
# 3                   1       NaN        1   31        66        175
# 4                   2       NaN        2   21        77        213
#
#   WritingPreference
# 0        Right hand
# 1         Left hand
# 2         Left hand
# 3        Right hand
# 4        Right hand

# %%
dffemale = pd.read_csv("ANSUR II FEMALE Public.csv")
dffemale.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# 2                      237               196                397
# 3                      240               188                384
# 4                      217               182                378
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        315               263               466
# 1                        272               250               430
# 2                        300               276               450
# 3                        364               276               484
# 4                        320               336               525
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  65               338                        301
# 1                  64               294                        270
# 2                  69               309                        270
# 3                  68               340                        294
# 4                  67               300                        295
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 141                  1011           223            836
# 1                 126                   893           186            900
# 2                 128                   987           204            861
# 3                 144                  1012           253            897
# 4                 135                  1281           284            811
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                587                     476                360
# 1                583                     483                350
# 2                583                     466                384
# 3                599                     471                372
# 4                607                     467                433
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1336           274                 922         245         1095
# 1             1440           261                 839         206         1234
# 2             1451           287                 874         223         1226
# 3             1430           269                1008         285         1170
# 4             1362           305                1089         290         1112
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           759                    557                             310
# 1           835                    549                             329
# 2           821                    643                             374
# 3           804                    640                             351
# 4           726                    686                             356
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          35         65             16              220               713
# 1          32         60             23              208               726
# 2          36         65             26              204               790
# 3          38         62             22              244               775
# 4          34         65             18              233               732
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                     91         246                        316
# 1                     91         249                        341
# 2                    100         265                        343
# 3                     97         265                        331
# 4                     88         247                        339
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         265                    517                432
# 1                         247                    468                463
# 2                         262                    488                469
# 3                         309                    529                455
# 4                         260                    596                447
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1028           75                182         184
# 1                 1117           78                187         189
# 2                 1060           84                198         195
# 3                 1069           80                192         186
# 4                 1039           78                183         187
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          141                548         191                     314
# 1          138                535         180                     307
# 2          146                588         207                     331
# 3          153                593         206                     332
# 4          140                522         181                     308
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           69         345                388                 966
# 1           60         315                335                1048
# 2           70         356                399                1043
# 3           68         337                402                1029
# 4           63         448                499                 964
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    645         363          399                   435
# 1                    595         340          375                   483
# 2                    655         345          399                   470
# 3                    655         392          435                   469
# 4                    635         428          435                   440
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                496                             447                      55
# 1                532                             492                      69
# 2                530                             469                      64
# 3                520                             478                      67
# 4                491                             441                      63
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      404                  118                335
# 1                      334                  115                302
# 2                      401                  135                325
# 3                      402                  118                357
# 4                      479                  114                340
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    368                           1268         113
# 1                    345                           1389         110
# 2                    369                           1414         122
# 3                    386                           1329         115
# 4                    358                           1350         116
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              362                   235                   1062
# 1              426                   259                   1014
# 2              398                   258                   1049
# 3              394                   250                   1121
# 4              345                   242                   1151
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  327             148            803                     809
# 1                  346             142            835                     810
# 2                  362             164            904                     855
# 3                  333             157            875                     815
# 4                  329             156            824                     810
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            513  1647     1560                 1280            1013
# 1            575  1751     1665                 1372            1107
# 2            568  1779     1711                 1383            1089
# 3            536  1708     1660                 1358            1065
# 4            559  1702     1572                 1292            1030
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 622             174            736           430
# 1                 524             152            771           475
# 2                 577             164            814           458
# 3                 679             187            736           463
# 4                 766             197            766           429
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               110                  844                           1488
# 1               125                  901                           1470
# 2               129                  882                           1542
# 3               125                  866                           1627
# 4               116                  800                           1698
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              406           295                 850         217
# 1              422           254                 708         168
# 2              419           269                 727         159
# 3              451           302                 923         235
# 4              452           405                1163         300
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      345                   942       657
# 1                      329                  1032       534
# 2                      367                  1035       663
# 3                      371                   999       782
# 4                      380                   911       886
#
#    wristcircumference  wristheight  Gender      Date Installation  \
# 0                 152          756  Female  5-Oct-10    Fort Hood
# 1                 155          815  Female  5-Oct-10    Fort Hood
# 2                 162          799  Female  5-Oct-10    Fort Hood
# 3                 173          818  Female  5-Oct-10    Fort Hood
# 4                 152          762  Female  5-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army          Combat Support        92Y               Germany
# 1  Regular Army  Combat Service Support        25U            California
# 2  Regular Army  Combat Service Support        35D                 Texas
# 3  Regular Army  Combat Service Support        25U  District of Columbia
# 4  Regular Army             Combat Arms        42A                 Texas
#
#    SubjectNumericRace           Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   2                 NaN        2   26        61        142
# 1                   3             Mexican        3   21        64        120
# 2                   1                 NaN        1   23        68        147
# 3                   8  Caribbean Islander        2   22        66        175
# 4                   1                 NaN        1   45        63        195
#
#   WritingPreference
# 0        Right hand
# 1        Right hand
# 2        Right hand
# 3        Right hand
# 4        Right hand

# %% [markdown]
# ## Explore Data

# %%
dffemale.SubjectId.sort_values()
# Out:
# 0        10037
# 1        10038
# 2        10042
# 3        10043
# 4        10051
#          ...
# 1981     29501
# 1982     29502
# 1983     29503
# 1984     29511
# 1985    920103
# Name: SubjectId, Length: 1986, dtype: int64

# %%
dfmale.subjectid.sort_values()
# Out:
# 0       10027
# 1       10032
# 2       10033
# 3       10092
# 4       10093
#         ...
# 4077    29442
# 4078    29443
# 4079    29447
# 4080    29451
# 4081    29452
# Name: subjectid, Length: 4082, dtype: int64

# %%
dffemale.columns
# Out:
# Index(['SubjectId', 'abdominalextensiondepthsitting', 'acromialheight',
#        'acromionradialelength', 'anklecircumference', 'axillaheight',
#        'balloffootcircumference', 'balloffootlength', 'biacromialbreadth',
#        'bicepscircumferenceflexed',
#        ...
#        'Branch', 'PrimaryMOS', 'SubjectsBirthLocation', 'SubjectNumericRace',
#        'Ethnicity', 'DODRace', 'Age', 'Heightin', 'Weightlbs',
#        'WritingPreference'],
#       dtype='object', length=108)

# %%
dfmale.columns
# Out:
# Index(['subjectid', 'abdominalextensiondepthsitting', 'acromialheight',
#        'acromionradialelength', 'anklecircumference', 'axillaheight',
#        'balloffootcircumference', 'balloffootlength', 'biacromialbreadth',
#        'bicepscircumferenceflexed',
#        ...
#        'Branch', 'PrimaryMOS', 'SubjectsBirthLocation', 'SubjectNumericRace',
#        'Ethnicity', 'DODRace', 'Age', 'Heightin', 'Weightlbs',
#        'WritingPreference'],
#       dtype='object', length=108)

# %%
dffemale.rename({"SubjectId" : "subjectid"}, axis=1, inplace=True)

# %%
df = pd.concat([dffemale, dfmale], axis=0, ignore_index="True")

# %%
df.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# 2                      237               196                397
# 3                      240               188                384
# 4                      217               182                378
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        315               263               466
# 1                        272               250               430
# 2                        300               276               450
# 3                        364               276               484
# 4                        320               336               525
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  65               338                        301
# 1                  64               294                        270
# 2                  69               309                        270
# 3                  68               340                        294
# 4                  67               300                        295
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 141                  1011           223            836
# 1                 126                   893           186            900
# 2                 128                   987           204            861
# 3                 144                  1012           253            897
# 4                 135                  1281           284            811
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                587                     476                360
# 1                583                     483                350
# 2                583                     466                384
# 3                599                     471                372
# 4                607                     467                433
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1336           274                 922         245         1095
# 1             1440           261                 839         206         1234
# 2             1451           287                 874         223         1226
# 3             1430           269                1008         285         1170
# 4             1362           305                1089         290         1112
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           759                    557                             310
# 1           835                    549                             329
# 2           821                    643                             374
# 3           804                    640                             351
# 4           726                    686                             356
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          35         65             16              220               713
# 1          32         60             23              208               726
# 2          36         65             26              204               790
# 3          38         62             22              244               775
# 4          34         65             18              233               732
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                     91         246                        316
# 1                     91         249                        341
# 2                    100         265                        343
# 3                     97         265                        331
# 4                     88         247                        339
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         265                    517                432
# 1                         247                    468                463
# 2                         262                    488                469
# 3                         309                    529                455
# 4                         260                    596                447
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1028           75                182         184
# 1                 1117           78                187         189
# 2                 1060           84                198         195
# 3                 1069           80                192         186
# 4                 1039           78                183         187
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          141                548         191                     314
# 1          138                535         180                     307
# 2          146                588         207                     331
# 3          153                593         206                     332
# 4          140                522         181                     308
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           69         345                388                 966
# 1           60         315                335                1048
# 2           70         356                399                1043
# 3           68         337                402                1029
# 4           63         448                499                 964
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    645         363          399                   435
# 1                    595         340          375                   483
# 2                    655         345          399                   470
# 3                    655         392          435                   469
# 4                    635         428          435                   440
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                496                             447                      55
# 1                532                             492                      69
# 2                530                             469                      64
# 3                520                             478                      67
# 4                491                             441                      63
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      404                  118                335
# 1                      334                  115                302
# 2                      401                  135                325
# 3                      402                  118                357
# 4                      479                  114                340
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    368                           1268         113
# 1                    345                           1389         110
# 2                    369                           1414         122
# 3                    386                           1329         115
# 4                    358                           1350         116
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              362                   235                   1062
# 1              426                   259                   1014
# 2              398                   258                   1049
# 3              394                   250                   1121
# 4              345                   242                   1151
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  327             148            803                     809
# 1                  346             142            835                     810
# 2                  362             164            904                     855
# 3                  333             157            875                     815
# 4                  329             156            824                     810
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            513  1647     1560                 1280            1013
# 1            575  1751     1665                 1372            1107
# 2            568  1779     1711                 1383            1089
# 3            536  1708     1660                 1358            1065
# 4            559  1702     1572                 1292            1030
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 622             174            736           430
# 1                 524             152            771           475
# 2                 577             164            814           458
# 3                 679             187            736           463
# 4                 766             197            766           429
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               110                  844                           1488
# 1               125                  901                           1470
# 2               129                  882                           1542
# 3               125                  866                           1627
# 4               116                  800                           1698
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              406           295                 850         217
# 1              422           254                 708         168
# 2              419           269                 727         159
# 3              451           302                 923         235
# 4              452           405                1163         300
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      345                   942       657
# 1                      329                  1032       534
# 2                      367                  1035       663
# 3                      371                   999       782
# 4                      380                   911       886
#
#    wristcircumference  wristheight  Gender      Date Installation  \
# 0                 152          756  Female  5-Oct-10    Fort Hood
# 1                 155          815  Female  5-Oct-10    Fort Hood
# 2                 162          799  Female  5-Oct-10    Fort Hood
# 3                 173          818  Female  5-Oct-10    Fort Hood
# 4                 152          762  Female  5-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army          Combat Support        92Y               Germany
# 1  Regular Army  Combat Service Support        25U            California
# 2  Regular Army  Combat Service Support        35D                 Texas
# 3  Regular Army  Combat Service Support        25U  District of Columbia
# 4  Regular Army             Combat Arms        42A                 Texas
#
#    SubjectNumericRace           Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   2                 NaN        2   26        61        142
# 1                   3             Mexican        3   21        64        120
# 2                   1                 NaN        1   23        68        147
# 3                   8  Caribbean Islander        2   22        66        175
# 4                   1                 NaN        1   45        63        195
#
#   WritingPreference
# 0        Right hand
# 1        Right hand
# 2        Right hand
# 3        Right hand
# 4        Right hand

# %%
df.describe()
# Out:
#            subjectid  abdominalextensiondepthsitting  acromialheight  \
# count    6068.000000                     6068.000000     6068.000000
# mean    20757.198418                      246.468688     1406.161338
# std     13159.390894                       37.400106       79.091048
# min     10027.000000                      155.000000     1115.000000
# 25%     14841.750000                      219.000000     1350.000000
# 50%     20063.500000                      242.000000     1410.000000
# 75%     27234.500000                      271.000000     1462.000000
# max    920103.000000                      451.000000     1683.000000
#
#        acromionradialelength  anklecircumference  axillaheight  \
# count            6068.000000         6068.000000   6068.000000
# mean              327.374423          224.891397   1299.608767
# std                20.720018           16.051833     72.022286
# min               249.000000          156.000000   1038.000000
# 25%               313.000000          214.000000   1249.000000
# 50%               328.000000          225.000000   1302.000000
# 75%               341.250000          235.000000   1349.000000
# max               393.000000          293.000000   1553.000000
#
#        balloffootcircumference  balloffootlength  biacromialbreadth  \
# count               6068.00000       6068.000000        6068.000000
# mean                 244.19265        194.754614         399.204186
# std                   16.84502         13.516368          30.236914
# min                  186.00000        151.000000         283.000000
# 25%                  232.00000        185.000000         376.000000
# 50%                  245.00000        195.000000         404.000000
# 75%                  256.00000        204.000000         421.000000
# max                  306.00000        245.000000         489.000000
#
#        bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# count                6068.000000       6068.000000       6068.000000
# mean                  340.934245        274.735003        490.754450
# std                    41.519866         19.221034         42.135535
# min                   216.000000        197.000000        357.000000
# 25%                   311.000000        262.000000        460.000000
# 50%                   341.000000        274.000000        492.000000
# 75%                   370.000000        288.000000        520.000000
# max                   490.000000        362.000000        637.000000
#
#        bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# count         6068.000000       6068.000000                6068.000000
# mean            72.252637        324.896506                 306.636124
# std              5.344590         17.087501                  20.794166
# min             55.000000        267.000000                 245.000000
# 25%             68.000000        314.000000                 292.000000
# 50%             72.000000        326.000000                 307.000000
# 75%             76.000000        336.000000                 321.000000
# max             91.000000        385.000000                 390.000000
#
#        bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# count         6068.000000           6068.000000   6068.000000    6068.000000
# mean           139.723467           1020.084707    241.619974     870.152274
# std              7.308457             76.422643     26.482986      54.822574
# min            116.000000            737.000000    168.000000     656.000000
# 25%            135.000000            968.000000    222.000000     832.000000
# 50%            140.000000           1017.000000    241.000000     868.000000
# 75%            145.000000           1068.000000    259.000000     906.250000
# max            174.000000           1341.000000    349.000000    1080.000000
#
#        buttockkneelength  buttockpopliteallength  calfcircumference  \
# count        6068.000000             6068.000000         6068.00000
# mean          608.999176              497.097561          386.04120
# std            33.792839               29.082390           30.64718
# min           466.000000              367.000000          266.00000
# 25%           586.000000              477.000000          364.75000
# 50%           609.000000              497.000000          385.00000
# 75%           632.000000              517.000000          406.00000
# max           736.000000              605.000000          523.00000
#
#        cervicaleheight  chestbreadth  chestcircumference   chestdepth  \
# count      6068.000000   6068.000000         6068.000000  6068.000000
# mean       1477.490442    282.859097         1022.098879   251.738464
# std          84.323707     20.659397          100.671751    26.777843
# min        1184.000000    213.000000          695.000000   170.000000
# 25%        1418.000000    268.000000          949.000000   233.000000
# 50%        1484.000000    283.000000         1020.500000   251.000000
# 75%        1537.000000    297.000000         1092.000000   270.000000
# max        1738.000000    363.000000         1469.000000   383.000000
#
#        chestheight  crotchheight  crotchlengthomphalion  \
# count  6068.000000   6068.000000            6068.000000
# mean   1252.013184    825.110086             621.851681
# std      79.583972     54.748240              45.332961
# min     984.000000    610.000000             473.000000
# 25%    1196.000000    787.000000             590.000000
# 50%    1259.000000    825.000000             620.000000
# 75%    1309.000000    863.000000             651.000000
# max    1506.000000   1031.000000             799.000000
#
#        crotchlengthposterioromphalion   earbreadth    earlength  \
# count                     6068.000000  6068.000000  6068.000000
# mean                       351.315920    35.132169    62.625906
# std                         29.944868     3.231469     4.876264
# min                        243.000000    25.000000    46.000000
# 25%                        330.000000    33.000000    59.000000
# 50%                        350.000000    35.000000    62.000000
# 75%                        372.000000    37.000000    66.000000
# max                        468.000000    46.000000    81.000000
#
#        earprotrusion  elbowrestheight  eyeheightsitting  \
# count    6068.000000      6068.000000       6068.000000
# mean       22.263349       240.911338        785.914469
# std         3.172715        28.509447         41.865795
# min        13.000000       138.000000        654.000000
# 25%        20.000000       222.000000        757.000000
# 50%        22.000000       241.000000        787.000000
# 75%        24.000000       261.000000        815.000000
# max        34.000000       345.000000        912.000000
#
#        footbreadthhorizontal   footlength  forearmcenterofgriplength  \
# count            6068.000000  6068.000000                6068.000000
# mean               98.865359   263.033619                 338.766645
# std                 6.657916    17.390971                  23.244742
# min                77.000000   198.000000                 258.000000
# 25%                94.000000   251.000000                 322.000000
# 50%                99.000000   264.000000                 340.000000
# 75%               104.000000   276.000000                 355.000000
# max               126.000000   323.000000                 416.000000
#
#        forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# count                 6068.000000            6068.000000        6068.000000
# mean                   295.010712             552.075972         467.007086
# std                     30.049715              62.368049          30.034820
# min                    200.000000             376.000000         342.000000
# 25%                    272.000000             505.000000         446.000000
# 50%                    297.000000             553.000000         469.000000
# 75%                    317.000000             597.000000         488.000000
# max                    402.000000             778.000000         574.000000
#
#        functionalleglength  handbreadth  handcircumference   handlength  \
# count          6068.000000  6068.000000        6068.000000  6068.000000
# mean           1102.049275    84.953362         203.861404   189.286585
# std              68.545784     6.346510          15.551424    11.505788
# min             835.000000    67.000000         152.000000   145.000000
# 25%            1055.000000    80.000000         192.000000   181.000000
# 50%            1104.000000    86.000000         206.000000   189.500000
# 75%            1149.000000    90.000000         215.000000   197.000000
# max            1316.000000   105.000000         248.000000   239.000000
#
#        headbreadth  headcircumference   headlength  heelanklecircumference  \
# count  6068.000000        6068.000000  6068.000000             6068.000000
# mean    152.182762         570.035267   196.334871              332.622940
# std       6.235692          18.291139     8.485374               22.460776
# min     131.000000         500.000000   168.000000              258.000000
# 25%     148.000000         557.000000   191.000000              316.000000
# 50%     152.000000         570.000000   197.000000              334.000000
# 75%     156.000000         582.000000   202.000000              348.000000
# max     180.000000         635.000000   225.000000              403.000000
#
#        heelbreadth   hipbreadth  hipbreadthsitting  iliocristaleheight  \
# count  6068.000000  6068.000000        6068.000000         6068.000000
# mean     70.756922   348.385465         385.733355         1040.059492
# std       5.932626    25.297828          32.399905           59.867016
# min      48.000000   264.000000         280.000000          816.000000
# 25%      67.000000   332.000000         364.000000          998.000000
# 50%      70.000000   347.000000         384.000000         1040.000000
# 75%      75.000000   364.000000         406.000000         1081.000000
# max      93.000000   473.000000         541.000000         1253.000000
#
#        interpupillarybreadth   interscyei  interscyeii  kneeheightmidpatella  \
# count            6068.000000  6068.000000  6068.000000           6068.000000
# mean              632.602011   412.037739   432.340804            475.512854
# std                36.508997    43.065925    38.658239             33.074714
# min               510.000000   270.000000   306.000000            346.000000
# 25%               610.000000   381.000000   405.000000            452.000000
# 50%               635.000000   411.000000   434.000000            476.000000
# 75%               655.000000   442.000000   460.000000            497.000000
# max               770.000000   562.000000   577.000000            612.000000
#
#        kneeheightsitting  lateralfemoralepicondyleheight  \
# count        6068.000000                     6068.000000
# mean          540.124918                      483.239618
# std            34.203131                       29.359616
# min           407.000000                      352.000000
# 25%           516.000000                      463.000000
# 50%           541.000000                      483.000000
# 75%           564.000000                      503.000000
# max           666.000000                      594.000000
#
#        lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# count             6068.000000              6068.000000          6068.000000
# mean                69.580422               406.479895           119.518787
# std                  7.270059                33.228317             7.879897
# min                 43.000000               290.000000            91.000000
# 25%                 65.000000               384.000000           114.000000
# 50%                 70.000000               405.000000           120.000000
# 75%                 75.000000               427.000000           125.000000
# max                 93.000000               600.000000           156.000000
#
#        neckcircumference  neckcircumferencebase  \
# count        6068.000000            6068.000000
# mean          375.441167             413.834707
# std            39.770240              38.156374
# min           275.000000             302.000000
# 25%           342.000000             382.000000
# 50%           380.000000             418.000000
# 75%           404.000000             442.000000
# max           514.000000             545.000000
#
#        overheadfingertipreachsitting   palmlength  poplitealheight  \
# count                    6068.000000  6068.000000      6068.000000
# mean                     1388.404417   113.916612       416.187047
# std                        85.849174     7.136566        31.266447
# min                      1111.000000    88.000000       305.000000
# 25%                      1327.000000   109.000000       394.000000
# 50%                      1393.000000   114.000000       417.000000
# 75%                      1449.000000   118.000000       438.000000
# max                      1651.000000   140.000000       525.000000
#
#        radialestylionlength  shouldercircumference  shoulderelbowlength  \
# count           6068.000000            6068.000000          6068.000000
# mean             259.192320            1129.362228           354.083553
# std               19.777577              92.828849            22.598591
# min              169.000000             852.000000           271.000000
# 25%              245.000000            1057.000000           338.000000
# 50%              260.000000            1139.000000           355.000000
# 75%              273.000000            1197.000000           370.000000
# max              328.000000            1413.000000           423.000000
#
#        shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  \
# count     6068.000000    6068.000000             6068.000000    6068.000000
# mean       145.072676     898.107779              866.665293     576.899967
# std         12.424295      45.299042               57.524072      38.258587
# min        107.000000     750.000000              636.000000     410.000000
# 25%        137.000000     866.000000              824.000000     550.000000
# 50%        145.000000     900.000000              872.000000     578.000000
# 75%        154.000000     930.000000              910.000000     603.000000
# max        185.000000    1039.000000             1058.000000     709.000000
#
#               span      stature  suprasternaleheight  tenthribheight  \
# count  6068.000000  6068.000000          6068.000000     6068.000000
# mean   1763.794825  1714.406065          1402.949077     1099.587179
# std     110.832751    90.015336            78.768058       60.540920
# min    1323.000000  1409.000000          1131.000000      868.000000
# 25%    1686.750000  1651.750000          1348.000000     1057.000000
# 50%    1771.000000  1719.000000          1407.000000     1099.000000
# 75%    1842.000000  1779.000000          1459.000000     1141.000000
# max    2121.000000  1993.000000          1650.000000     1305.000000
#
#        thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# count         6068.000000     6068.000000    6068.000000   6068.000000
# mean           622.198748      176.336355     789.695616    458.244562
# std             57.750677       16.220270      53.823572     29.759325
# min            412.000000      121.000000     602.000000    344.000000
# 25%            583.000000      165.000000     753.000000    437.000000
# 50%            621.000000      175.000000     792.000000    458.000000
# 75%            659.000000      187.000000     826.000000    478.000000
# max            870.000000      259.000000     998.000000    584.000000
#
#        tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# count       6068.000000          6068.000000                    6068.000000
# mean         129.617996           882.739947                    1630.309492
# std            6.659692            54.402819                      98.624125
# min          105.000000           660.000000                    1342.000000
# 25%          125.000000           845.000000                    1558.000000
# 50%          130.000000           882.000000                    1628.000000
# 75%          134.000000           918.000000                    1695.000000
# max          150.000000          1095.000000                    1991.000000
#
#        waistbacklength  waistbreadth  waistcircumference   waistdepth  \
# count      6068.000000   6068.000000         6068.000000  6068.000000
# mean        460.524720    317.750000          914.501483   229.674028
# std          36.677909     36.363125          114.274513    35.613193
# min         345.000000    211.000000          611.000000   138.000000
# 25%         435.000000    292.000000          829.000000   203.000000
# 50%         463.000000    316.000000          907.000000   226.000000
# 75%         486.000000    343.000000          992.000000   252.250000
# max         598.000000    461.000000         1379.000000   406.000000
#
#        waistfrontlengthsitting  waistheightomphalion     weightkg  \
# count              6068.000000           6068.000000  6068.000000
# mean                377.003790           1031.501154   797.093935
# std                  31.617723             62.702388   156.528164
# min                 289.000000            805.000000   358.000000
# 25%                 355.000000            988.000000   682.000000
# 50%                 375.000000           1033.000000   785.000000
# 75%                 398.000000           1076.000000   896.000000
# max                 494.000000           1245.000000  1442.000000
#
#        wristcircumference  wristheight  SubjectNumericRace      DODRace  \
# count         6068.000000  6068.000000         6068.000000  6068.000000
# mean           169.002966   830.059987           17.515326     1.615030
# std             13.124513    47.650519          550.949948     0.979156
# min            124.000000   672.000000            1.000000     1.000000
# 25%            159.000000   797.000000            1.000000     1.000000
# 50%            170.000000   830.000000            1.000000     1.000000
# 75%            179.000000   863.000000            2.000000     2.000000
# max            216.000000  1009.000000        42351.000000     8.000000
#
#                Age     Heightin    Weightlbs
# count  6068.000000  6068.000000  6068.000000
# mean     29.761206    68.257251   174.749670
# std       8.674650     3.861954    33.691952
# min      17.000000    56.000000     0.000000
# 25%      23.000000    66.000000   150.000000
# 50%      28.000000    68.000000   173.000000
# 75%      36.000000    71.000000   196.000000
# max      58.000000    94.000000   321.000000

# %%
df.sample(1)
# Out:
#      abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 765                             216            1333                    308
#
#      anklecircumference  axillaheight  balloffootcircumference  \
# 765                 206          1255                      243
#
#      balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 765               191                357                        336
#
#      bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  \
# 765               252               437                  68               321
#
#      bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 765                        302                 134                   995
#
#      buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  \
# 765           236            870                605                     503
#
#      calfcircumference  cervicaleheight  chestbreadth  chestcircumference  \
# 765                363             1425           262                 975
#
#      chestdepth  chestheight  crotchheight  crotchlengthomphalion  \
# 765         267         1171           816                    633
#
#      crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 765                             333          32         54             17
#
#      elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 765              223               737                     95         258
#
#      forearmcenterofgriplength  forearmcircumferenceflexed  \
# 765                        336                         268
#
#      forearmforearmbreadth  forearmhandlength  functionalleglength  \
# 765                    465                463                 1061
#
#      handbreadth  handcircumference  handlength  headbreadth  \
# 765           83                193         196          150
#
#      headcircumference  headlength  heelanklecircumference  heelbreadth  \
# 765                560         191                     317           71
#
#      hipbreadth  hipbreadthsitting  iliocristaleheight  interpupillarybreadth  \
# 765         338                396                1000                    615
#
#      interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  \
# 765         365          379                   471                534
#
#      lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 765                             484                      65
#
#      lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 765                      385                  117                336
#
#      neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 765                    367                           1279         109
#
#      poplitealheight  radialestylionlength  shouldercircumference  \
# 765              405                   253                   1025
#
#      shoulderelbowlength  shoulderlength  sittingheight  \
# 765                  328             152            846
#
#      sleevelengthspinewrist  sleeveoutseam  span  stature  \
# 765                     818            546  1688     1653
#
#      suprasternaleheight  tenthribheight  thighcircumference  thighclearance  \
# 765                 1349            1067                 623             171
#
#      thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  \
# 765            747           455               126                  874
#
#      verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  \
# 765                           1517              409           278
#
#      waistcircumference  waistdepth  waistfrontlengthsitting  \
# 765                 815         190                      332
#
#      waistheightomphalion  weightkg  wristcircumference  wristheight  Gender  \
# 765                  1024       682                 157          794       0
#
#      DODRace  Age
# 765        2   44

# %%
df.Ethnicity.isnull().sum()
# Out:
# 4647

# %%
df.SubjectsBirthLocation.value_counts()

# %%
df.drop(["Ethnicity", "WritingPreference", "SubjectsBirthLocation", "PrimaryMOS", "Branch", "Component", "Installation", "subjectid", "Date", "Heightin", "Weightlbs", "SubjectNumericRace"], axis=1, inplace=True)

# %%
df["Gender"] = df.Gender.apply(lambda x: 0 if x == "Female" else 1)

# %%
df.Gender.value_counts()
# Out:
# 1    4082
# 0    1986
# Name: Gender, dtype: int64

# %%
df.info(verbose=True)

# %%
df.DODRace.value_counts()
# Out:
# 1    3792
# 2    1298
# 3     679
# 4     188
# 6      59
# 5      49
# 8       3
# Name: DODRace, dtype: int64

# %%
df.drop(df[df["DODRace"]] == [4, 5, 6, 8], axis = 0) 

# ????

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %% [markdown]
# ### Logistic Model GridsearchCV

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %% [markdown]
# ###  SVC Model GridsearchCV

# %% [markdown]
# ## 3. RF

# %% [markdown]
# ### Vanilla RF Model

# %% [markdown]
# ### RF Model GridsearchCV

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ##  Smote implement

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %% [markdown]
# ## SVC Over/Under Sampling

# %% [markdown]
# ## Xgboost Over/ Under Sampling

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %%
from sklearn.metrics import matthews_corrcoef

matthews_corrcoef(y_test, y_pred)
# Out:
# 0.7380728719663084

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)
# Out:
# 0.7376215262514891

# %% [markdown]
# #  SHAP
#
# https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.40.0-cp38-cp38-win_amd64.whl (431 kB)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\madcat\anaconda3\lib\site-packages (from shap) (4.59.0)
# Requirement already satisfied: numba in c:\users\madcat\anaconda3\lib\site-packages (from shap) (0.53.1)
# Collecting packaging>20.9
#   Downloading packaging-21.2-py3-none-any.whl (40 kB)
# Requirement already satisfied: scikit-learn in c:\users\madcat\anaconda3\lib\site-packages (from shap) (0.24.1)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.6.2)
# Requirement already satisfied: cloudpickle in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.6.0)
# Requirement already satisfied: pandas in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.3.4)
# Requirement already satisfied: numpy in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.20.1)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in c:\users\madcat\anaconda3\lib\site-packages (from packaging>20.9->shap) (2.4.7)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\madcat\anaconda3\lib\site-packages (from numba->shap) (0.36.0)
# Requirement already satisfied: setuptools in c:\users\madcat\anaconda3\lib\site-packages (from numba->shap) (52.0.0.post20210125)
# Requirement already satisfied: pytz>=2017.3 in c:\users\madcat\anaconda3\lib\site-packages (from pandas->shap) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\madcat\anaconda3\lib\site-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\madcat\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\madcat\anaconda3\lib\site-packages (from scikit-learn->shap) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\madcat\anaconda3\lib\site-packages (from scikit-learn->shap) (2.1.0)
# Installing collected packages: slicer, packaging, shap
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.9
#     Uninstalling packaging-20.9:
#       Successfully uninstalled packaging-20.9
# Successfully installed packaging-21.2 shap-0.40.0 slicer-0.0.7

# %%
import shap
explainer = shap.Explainer(log_model,X_train)
start_index = 203
end_index = 204
shap_values = explainer.shap_values(X_test[start_index:end_index])

# %%
shap_values

# %%
print(shap_values[0].shape)
# Out:
# (1, 232)

# %%
# %% >> Visualize local predictions
shap.initjs()
# Force plot
prediction = log_model.predict(X_test[start_index:end_index])[0]
print(f"The log_model predicted: {prediction}")
shap.force_plot(explainer.expected_value[1],
                shap_values[1],
                X_test[start_index:end_index], # for values
                feature_names= X.columns,)

# %%
shap.summary_plot(shap_values, X_train,max_display=300,feature_names = X.columns)

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
